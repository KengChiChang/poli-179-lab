# %%
import pandas as pd

news_df = pd.read_json("../data/News_Category_Dataset_v3.json", lines=True)
news_df
# Out:
#                                                      link  \
# 0       https://www.huffpost.com/entry/covid-boosters-...
# 1       https://www.huffpost.com/entry/american-airlin...
# 2       https://www.huffpost.com/entry/funniest-tweets...
# 3       https://www.huffpost.com/entry/funniest-parent...
# 4       https://www.huffpost.com/entry/amy-cooper-lose...
# ...                                                   ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# ...

# %%
category_select = ["POLITICS", "ENTERTAINMENT", "BUSINESS", "SPORTS", "TRAVEL"]
news_df = news_df.query('category == @category_select & short_description != "" & headline != "" & date >= "2016-01-01"')
news_df
# Out:
#                                                     link  \
# 17     https://www.huffpost.com/entry/dodgers-basebal...
# 20     https://www.huffpost.com/entry/golden-globes-r...
# 21     https://www.huffpost.com/entry/biden-us-forces...
# 24     https://www.huffpost.com/entry/ukraine-festiva...
# 26     https://www.huffpost.com/entry/2022-wnba-final...
# ...                                                  ...
# 79234  https://www.huffingtonpost.com/entry/get-your-...
# 79235  https://www.huffingtonpost.com/entry/is-cosby-...
# 79237  https://www.huffingtonpost.com/entry/whither-a...
# 79238  https://www.huffingtonpost.com/entry/sport-and...
# 79242  https://www.huffingtonpost.com/entry/virginia-...
#
#                                                 headline       category  \
# 17     Maury Wills, Base-Stealing Shortstop For Dodge...         SPORTS
# 20     Golden Globes Returning To NBC In January Afte...  ENTERTAINMENT
# ...

# %%
news_df['category'].value_counts()
# Out:
# POLITICS         26395
# ENTERTAINMENT     9622
# SPORTS            2270
# BUSINESS          1358
# TRAVEL             707
# Name: category, dtype: int64

# %%
news_df['text'] = news_df['headline'] + '  |||  ' + news_df['short_description']
# Out:
# /Users/kengchichang/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
news_df = news_df[['category', 'text']]

# %%
news_df_sample = pd.concat([
    news_df.query('category == "POLITICS"').sample(frac=500/25500, random_state=123),
    news_df.query('category == "ENTERTAINMENT"').sample(frac=500/9600, random_state=123),
    news_df.query('category == "TRAVEL"').sample(frac=500/700, random_state=123),
    news_df.query('category == "BUSINESS"').sample(frac=500/1350, random_state=123),
    news_df.query('category == "SPORTS"').sample(frac=500/2250, random_state=123)
])

# %%
news_df_sample['category'].value_counts()
# Out:
# POLITICS         518
# TRAVEL           505
# SPORTS           504
# BUSINESS         503
# ENTERTAINMENT    501
# Name: category, dtype: int64

# %%
news_df_sample['text'] = news_df_sample['text'].str.replace("’", "'")

# %%
news_df_sample.to_csv("../data/news_sample.csv", index=False, quoting=1)
